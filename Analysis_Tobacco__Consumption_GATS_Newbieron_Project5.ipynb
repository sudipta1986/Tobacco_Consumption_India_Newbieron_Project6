# %% [markdown]
# The Global Adult Tobacco Survey (GATS) provides a comprehensive and internationally recognized dataset on tobacco use among adults in various countries, including India. By analyzing the GATS data specific to India, we gain valuable insights into the prevalence, patterns, and determinants of tobacco consumption among its diverse population.
#
# This data analysis endeavor focuses on understanding the multifaceted landscape of tobacco use in India. We delve into key aspects such as the prevalence of smoking and smokeless tobacco use, regional variations, socio-demographic factors influencing tobacco consumption, and the health consequences associated with tobacco use.
#
# GATS data allows us to examine the prevalence of tobacco use across different age groups, genders, and socio-economic backgrounds, facilitating the identification of vulnerable population segments and disparities in tobacco consumption rates. Understanding these variations is essential for developing targeted interventions and policies to address the specific needs of diverse communities.
#
# Furthermore, we explore the influence of tobacco marketing, packaging, and pricing on consumer behavior, providing valuable insights into the effectiveness of tobacco control measures. By analyzing the GATS data, we can advocate for evidence-based policies that aim to reduce tobacco initiation and promote cessation.
#
# The health implications of tobacco use are significant and widespread. Through data analysis, we assess the impact of tobacco on various health outcomes, including the heightened risk of cardiovascular diseases, respiratory illnesses, and cancer. This analysis emphasizes the urgent need for comprehensive tobacco control strategies to safeguard public health.
#
# Additionally, we highlight successful initiatives and programs implemented to combat tobacco use in India, showcasing evidence-based interventions that have yielded positive results. By disseminating these success stories, we can inspire further efforts and collaborations to address the tobacco epidemic effectively.
#
# The insights drawn from the data analysis of tobacco use among Indians according to the Global Adult Tobacco Survey serve as a crucial foundation for evidence-based policymaking, public health campaigns, and targeted interventions. By understanding the complex dynamics of tobacco consumption, we can work towards creating a tobacco-free future for India, promoting health, and ensuring the well-being of its citizens.

# %%
# Import require library for creating charts.
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Import csv file for analysis.
gt=pd.read_csv('Tobacco Consumption India GATS.csv')
gt.head(30)
# Out:
#                                     State   Men  Women
# 0                          Andhra Pradesh  30.0   10.1
# 1             Andaman and Nicobar Islands   NaN    NaN
# 2                                   Assam  62.9   32.9
# 3                                   Bihar  43.4    6.9
# 4   Dadra and Nagar Haveli, Daman and Diu   NaN    NaN
# 5                                     Goa  15.3    4.0
# 6                                 Gujarat  35.5   10.4
# 7                        Himachal Pradesh  30.4    1.7
# 8                       Jammu and Kashmir  39.7    6.2
# 9                               Karnataka  35.2   10.3
# 10                                 Kerala  23.0    3.6
# 11                                 Ladakh   NaN    NaN
# 12                            Lakshadweep   NaN    NaN
# 13                            Maharashtra  35.5   17.1
# 14                                Manipur  62.5   47.8
# 15                              Meghalaya  59.8   34.2
# ...

# %%
# For checking rows and column in data set.
gt.shape
# Out:
# (22, 3)

# %%
# Check the data type.
gt.dtypes
# Out:
# State     object
# Men      float64
# Women    float64
# dtype: object

# %% [markdown]
# # **Analysis**

# %%
# This is the plot size configaration.
plt.figure(figsize=(10,10))

# Now we can use plot style but it's not mandatory.
sns.set_style("whitegrid")

# In order to sort the data in ascending order.
gt_sh = gt.sort_values(by=['State'],ascending=True)

# We used seaborn to making the diagram, Y axis is define 'State' and hue or we can say legend is define 'Men' columns and mention the data set.
tl = sns.barplot(y='State',x='Men', data=gt_sh)

# We created this forloop for mention the count on each bar.
for i in tl.containers:
  tl.bar_label(i, fmt='%.1f%%', label_type='edge')

plt.xlabel("Tobacco consumption by Men in '%'") # This is title of x axis.
plt.ylabel("States") # This is title of Y axis.
plt.title("Tobacco consumption by Men of each state in India") # This is Title of Diagram.
# Out:
# Text(0.5, 1.0, 'Tobacco consumption by Men of each state in India')

# %%
# This is the plot size configaration.
plt.figure(figsize=(10,10))

# Now we can use plot style but it's not mandatory.
sns.set_style("whitegrid")

# In order to sort the data in ascending order.
gt_sh = gt.sort_values(by=['State'],ascending=True)

# We used seaborn to making the diagram, Y axis is define 'State' and hue or we can say legend is define 'Women' columns and mention the data set.
ml = sns.barplot(y='State',x='Women', data=gt_sh)

# We created this forloop for mention the count on each bar.
for i in ml.containers:
  ml.bar_label(i, fmt='%.1f%%', label_type='edge')

plt.xlabel("Tobacco consumption by Women in '%'") # This is title of x axis.
plt.ylabel("States") # This is title of Y axis.
plt.title("Tobacco consumption by Women of each state in India") # This is Title of Diagram.
# Out:
# Text(0.5, 1.0, 'Tobacco consumption by Women of each state in India')

# %% [markdown]
# Following a comprehensive examination of the Global Adult Tobacco Survey data on tobacco consumption in India, it becomes evident that smoking significantly affects men more than women. State-wise comparisons reveal Tripura as the top-ranking state with the highest tobacco consumption for both genders, signaling the need for targeted interventions in this region. Conversely, states such as Himachal Pradesh,Kerala,Goa and Jammu and Kashmir demonstrate the lowest rates of tobacco consumption among women, showcasing successful efforts in these areas. Notably, Goa emerges as the state with the least tobacco consumption among men, followed closely by Kerala, Telangana, and Sikim. These findings highlight the importance of gender-specific approaches in addressing tobacco use and emphasize the significance of state-level strategies to combat the tobacco epidemic effectively. We don't have any data couple of states like
# Andaman,Dadra,Ladakh and Lakshadweep.

# %% [markdown]
# # **The top ten states in India with the highest tobacco consumption by Women**

# %%
# This is the plot size configaration.
plt.figure(figsize=(7,5))

# Now we can use plot style but it's not mandatory.
sns.set_style("whitegrid")

# In order to sort the data in ascending order.
gt_sh = gt.sort_values(by=['Women'],ascending=False).head(10)

# We used seaborn to making the diagram, Y axis is define 'State' and hue or we can say legend is define 'Women' columns and mention the data set.
sp = sns.barplot(y='State',x='Women', data=gt_sh)

# We created this forloop for mention the count on each bar.
for i in sp.containers:
  sp.bar_label(i, fmt='%.1f%%', label_type='edge')

plt.xlabel("Tobacco consumption by Women in '%'") # This is title of x axis.
plt.ylabel("States") # This is title of Y axis.
plt.title("Top Ten States Highest Tobacco consumption by Women in India") # This is Title of Diagram.
# Out:
# Text(0.5, 1.0, 'Top Ten States Highest Tobacco consumption by Women in India')

# %% [markdown]
# # **These states in India stand out for having the highest tobacco usage among Men**

# %%
# This is the plot size configaration.
plt.figure(figsize=(7,5))

# Now we can use plot style but it's not mandatory.
sns.set_style("whitegrid")

# In order to sort the data in ascending order.
gt_sh = gt.sort_values(by=['Men'],ascending=False).head(10)

# We used seaborn to making the diagram, Y axis is define 'State' and hue or we can say legend is define 'Women' columns and mention the data set.
sp = sns.barplot(y='State',x='Men', data=gt_sh)

# We created this forloop for mention the count on each bar.
for i in sp.containers:
  sp.bar_label(i, fmt='%.1f%%', label_type='edge')

plt.xlabel("Tobacco consumption by Men in '%'") # This is title of x axis.
plt.ylabel("States") # This is title of Y axis.
plt.title("Top Ten States Highest Tobacco consumption by Men in India") # This is Title of Diagram.
# Out:
# Text(0.5, 1.0, 'Top Ten States Highest Tobacco consumption by Men in India')

# %% [markdown]
# # **Women in these ten states of India have the lowest prevalence of tobacco use**

# %%
# This is the plot size configaration.
plt.figure(figsize=(7,5))

# Now we can use plot style but it's not mandatory.
sns.set_style("whitegrid")

# In order to sort the data in ascending order.
gt_sh = gt.sort_values(by=['Women'],ascending=True).head(10)

# We used seaborn to making the diagram, Y axis is define 'State' and hue or we can say legend is define 'Women' columns and mention the data set.
sp = sns.barplot(y='State',x='Women', data=gt_sh)

# We created this forloop for mention the count on each bar.
for i in sp.containers:
  sp.bar_label(i, fmt='%.1f%%', label_type='edge')

plt.xlabel("Tobacco consumption by Women in '%'") # This is title of x axis.
plt.ylabel("States") # This is title of Y axis.
plt.title("Top Ten States Lowest Tobacco consumption by Women in India") # This is Title of Diagram.
# Out:
# Text(0.5, 1.0, 'Top Ten States Lowest Tobacco consumption by Women in India')

# %% [markdown]
# # **These ten states in India report the lowest rates of tobacco usage among Men**

# %%
# This is the plot size configaration.
plt.figure(figsize=(7,5))

# Now we can use plot style but it's not mandatory.
sns.set_style("whitegrid")

# In order to sort the data in ascending order.
gt_sh = gt.sort_values(by=['Men'],ascending=True).head(10)

# We used seaborn to making the diagram, Y axis is define 'State' and hue or we can say legend is define 'Women' columns and mention the data set.
sp = sns.barplot(y='State',x='Men', data=gt_sh)

# We created this forloop for mention the count on each bar.
for i in sp.containers:
  sp.bar_label(i, fmt='%.1f%%', label_type='edge')

plt.xlabel("Tobacco consumption by Men in '%'") # This is title of x axis.
plt.ylabel("States") # This is title of Y axis.
plt.title("Top Ten States Lowest Tobacco consumption by Men in India") # This is Title of Diagram.
# Out:
# Text(0.5, 1.0, 'Top Ten States Lowest Tobacco consumption by Men in India')
